# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

transactions = pd.read_csv('/content/drive/MyDrive/Politician Trades/all_trades_cleaned_yahoo_prices.csv')
trades = pd.read_csv('/content/drive/MyDrive/Politician Trades/combined_trades.csv')

# %%
transactions
# Out:
#       Politician Name       Party Chamber State             Issuer Name  \
# 0          Tom Carper    Democrat  Senate    DE      Valero Energy Corp
# 1          Tom Carper    Democrat  Senate    DE            Enbridge Inc
# 2          Tom Carper    Democrat  Senate    DE     JPMorgan Chase & Co
# 3        Dan Newhouse  Republican   House    WA           Accenture PLC
# 4        Dan Newhouse  Republican   House    WA      Analog Devices Inc
# ...               ...         ...     ...   ...                     ...
# 33333  Alan Lowenthal    Democrat   House    CA  Americold Realty Trust
# 33334      Mark Green  Republican   House    TN  NGL Energy Partners LP
# 33335    Doug Lamborn  Republican   House    CO              NetApp Inc
# 33336    Doug Lamborn  Republican   House    CO              NetApp Inc
# 33337    Doug Lamborn  Republican   House    CO              NetApp Inc
#
#       Ticker Publication Date Transaction Date  Reporting Gap        Owner  \
# ...

# %%
trades[trades['Annualized Percentage Profit'] == 0]
# Out:
#           Politician Ticker  Annualized Percentage Profit  \
# 1     Alan Lowenthal     GM                           0.0
# 2     Alan Lowenthal   NFLX                           0.0
# 3     Alan Lowenthal    SCI                           0.0
# 4     Alan Lowenthal   SPGI                           0.0
# 5         Angus King     VZ                           0.0
# ...              ...    ...                           ...
# 4307     Zoe Lofgren   CSCO                           0.0
# 4309     Zoe Lofgren   GILD                           0.0
# 4310     Zoe Lofgren    GIS                           0.0
# 4311     Zoe Lofgren    HCA                           0.0
# 4313     Zoe Lofgren   QCOM                           0.0
#
#                                Purchase Transaction IDs  \
# 1                                         [20003756305]
# 2                            [20003720049, 20003720044]
# 3     [20003755446, 20003753966, 20003753924, 200037...
# ...
