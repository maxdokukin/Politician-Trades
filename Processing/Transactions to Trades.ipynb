# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/maxdokukin/Politician-Trades/main/Data/data/transactions_cleaned.csv')
df['Transaction Date'] = pd.to_datetime(df['Transaction Date'])
df.sort_values('Transaction Date')
df['Price'] = df['Price_0_days']
df
# Out:
#       Politician Name       Party Chamber State             Issuer Name  \
# 0          Tom Carper    Democrat  Senate    DE      Valero Energy Corp
# 1          Tom Carper    Democrat  Senate    DE            Enbridge Inc
# 2        Dan Newhouse  Republican   House    WA           Accenture PLC
# 3        Dan Newhouse  Republican   House    WA      Analog Devices Inc
# 4        Dan Newhouse  Republican   House    WA    Booking Holdings Inc
# ...               ...         ...     ...   ...                     ...
# 31584  Alan Lowenthal    Democrat   House    CA  Americold Realty Trust
# 31585      Mark Green  Republican   House    TN  NGL Energy Partners LP
# 31586    Doug Lamborn  Republican   House    CO              NetApp Inc
# 31587    Doug Lamborn  Republican   House    CO              NetApp Inc
# 31588    Doug Lamborn  Republican   House    CO              NetApp Inc
#
#       Ticker Publication Date Transaction Date  Reporting Gap        Owner  \
# 0        VLO       2024-05-01       2024-04-11             19       Spouse
# 1        ENB       2024-05-01       2024-04-11             19       Spouse
# 2        ACN       2024-04-26       2024-04-10             15       Spouse
# 3        ADI       2024-04-26       2024-04-10             15       Spouse
# 4       BKNG       2024-04-26       2024-04-10             15       Spouse
# ...      ...              ...              ...            ...          ...
# 31584   COLD       2021-03-24       2021-03-15              8       Spouse
# 31585    NGL       2021-03-21       2021-03-17              3  Undisclosed
# 31586   NTAP       2021-03-20       2021-03-19              0       Spouse
# 31587   NTAP       2021-03-20       2021-03-19              0  Undisclosed
# 31588   NTAP       2021-03-20       2021-03-19              0       Spouse
#
#       Transaction Type Value Range        Price  Transaction ID  Price_0_days  \
# 0                 SELL      1K–15K   177.039993     10000062280    177.039993
# 1                  BUY      1K–15K    34.549999     10000062281     34.549999
# 2                  BUY      1K–15K   324.399994     20003772725    324.399994
# 3                  BUY      1K–15K   196.330002     20003772726    196.330002
# 4                 SELL      1K–15K  3586.129883     20003772728   3586.129883
# ...                ...         ...          ...             ...           ...
# 31584             SELL     15K–50K    37.130001     20001621840     37.130001
# 31585              BUY     15K–50K     2.340000     20001620394      2.340000
# 31586             SELL     15K–50K    70.160004     20001621844     70.160004
# 31587             SELL      1K–15K    70.160004     20001621847     70.160004
# 31588             SELL      1K–15K    70.160004     20001621850     70.160004
#
#        Approx Transaction Amount  Approx Share Count
# 0                         8000.0                45.0
# 1                         8000.0               231.0
# 2                         8000.0                24.0
# 3                         8000.0                40.0
# 4                         8000.0                 2.0
# ...                          ...                 ...
# 31584                    32500.0               875.0
# 31585                    32500.0             13888.0
# 31586                    32500.0               463.0
# 31587                     8000.0               114.0
# 31588                     8000.0               114.0
#
# [31589 rows x 17 columns]

# %%
def calculate_trades(df):
    results = []

    grouped = df.groupby(['Politician Name', 'Ticker'])

    for (name, ticker), group in grouped:
        transactions = group.sort_values('Transaction Date').to_dict('records')

        buy_prices = []
        sell_prices = []
        buy_ids = []
        sell_ids = []
        buy_amounts = []
        sell_amounts = []
        buy_dates = []
        sell_dates = []
        buying = True

        for transaction in transactions:
            date = transaction['Transaction Date']
            if buying and transaction['Transaction Type'] == 'BUY':
                #adding to the current buy cycle
                buy_prices.append(transaction['Price'])
                buy_ids.append(transaction['Transaction ID'])
                buy_amounts.append(transaction['Approx Transaction Amount'])
                buy_dates.append(date)
            elif buying and transaction['Transaction Type'] == 'SELL' and len(buy_prices):
                #transition from buying to selling
                buying = False
                sell_prices.append(transaction['Price'])
                sell_ids.append(transaction['Transaction ID'])
                sell_amounts.append(transaction['Approx Transaction Amount'])
                sell_dates.append(date)
            elif not buying and transaction['Transaction Type'] == 'SELL':
                #adding to the current sell cycle
                sell_prices.append(transaction['Price'])
                sell_ids.append(transaction['Transaction ID'])
                sell_amounts.append(transaction['Approx Transaction Amount'])
                sell_dates.append(date)
            elif not buying and transaction['Transaction Type'] == 'BUY':
                #close the previous sell cycle before starting a new buy cycle
                if buy_prices and sell_prices:
                    cycle_results = process_cycle(transaction, buy_prices, sell_prices, buy_ids, sell_ids, buy_amounts, sell_amounts, buy_dates, sell_dates)
                    results.extend(cycle_results)

                buy_prices, sell_prices, buy_ids, sell_ids, buy_amounts, sell_amounts, buy_dates, sell_dates = [], [], [], [], [], [], [], []

                buying = True
                buy_prices.append(transaction['Price'])
                buy_ids.append(transaction['Transaction ID'])
                buy_amounts.append(transaction['Approx Transaction Amount'])
                buy_dates.append(date)

        if buy_prices and sell_prices:
            cycle_results = process_cycle(transaction, buy_prices, sell_prices, buy_ids, sell_ids, buy_amounts, sell_amounts, buy_dates, sell_dates)
            results.extend(cycle_results)

    return pd.DataFrame(results)

def process_cycle(transaction, buy_prices, sell_prices, buy_ids, sell_ids, buy_amounts, sell_amounts, buy_dates, sell_dates):
    if not buy_dates or not sell_dates:
        return []

    first_buy_date = min(buy_dates) if buy_dates else None
    last_sell_date = max(sell_dates) if sell_dates else None
    days_between = (last_sell_date - first_buy_date).days if first_buy_date and last_sell_date else 0

    if days_between > 0 and buy_prices and sell_prices:
        avg_buy_price = sum(buy_prices) / len(buy_prices)
        avg_sell_price = sum(sell_prices) / len(sell_prices)
        percentage_profit = (avg_sell_price - avg_buy_price) / avg_buy_price * 100
        annualized_profit = (percentage_profit / days_between) * 365
        return [{
            'Politician Name': transaction['Politician Name'],
            'Party': transaction['Party'],
            'Chamber': transaction['Chamber'],
            'State': transaction['State'],
            'Ticker': transaction['Ticker'],
            'Report Gap': transaction['Reporting Gap'],
            'Annualized Percentage Profit': annualized_profit,
            'Purchase Transaction IDs': buy_ids,
            'Sell Transaction IDs': sell_ids,
            'Total Purchase Amount': sum(buy_amounts),
            'Total Sell Amount': sum(sell_amounts),
            'Days Between': days_between
        }]
    return []

trades = calculate_trades(df)

# %%
trades.sort_values('Annualized Percentage Profit', ascending=False)
# Out:
#        Politician Name       Party Chamber State Ticker  Report Gap  \
# 1386      Marie Newman    Democrat   House    IL   PTON          26
# 722          Jim Banks  Republican   House    IN   RBLX          24
# 5158  Tommy Tuberville  Republican  Senate    AL   PYPL          39
# 3020         Ro Khanna    Democrat   House    CA  GOOGL          14
# 2108         Ro Khanna    Democrat   House    CA    ARE          33
# ...                ...         ...     ...   ...    ...         ...
# 4812         Ro Khanna    Democrat   House    CA     ZM          24
# 3445         Ro Khanna    Democrat   House    CA   LULU          11
# 5057        Tom Suozzi    Democrat   House    NY   UPST           4
# 3718         Ro Khanna    Democrat   House    CA   MTCH          28
# 3863         Ro Khanna    Democrat   House    CA   OKTA          31
#
#       Annualized Percentage Profit    Purchase Transaction IDs  \
# 1386                   3161.461424               [20003694412]
# 722                    1960.844078               [20003708653]
# 5158                   1630.887975               [10000060480]
# 3020                   1233.239019               [20003761778]
# 2108                   1200.598085               [20003768918]
# ...                            ...                         ...
# 4812                  -1095.760885               [20003684224]
# 3445                  -1247.404265               [20003772192]
# 5057                  -1909.892368  [20003723764, 20003723765]
# 3718                  -2354.066985               [20003757234]
# 3863                  -2863.003057               [20003741973]
#
#             Sell Transaction IDs  Total Purchase Amount  Total Sell Amount  \
# 1386               [20003694413]                 8000.0             8000.0
# 722   [20003708651, 20003708654]                32500.0            40500.0
# 5158               [10000060482]               175000.0           175000.0
# 3020  [20003762017, 20003761597]                32500.0            16000.0
# 2108               [20003769728]                 8000.0             8000.0
# ...                          ...                    ...                ...
# 4812               [20003684253]                 8000.0             8000.0
# 3445               [20003772110]                 8000.0             8000.0
# 5057  [20003723763, 20003723766]                65000.0            16000.0
# 3718               [20003757516]                 8000.0            32500.0
# 3863               [20003741427]                 8000.0             8000.0
#
#       Days Between
# 1386             2
# 722              7
# 5158             1
# 3020             2
# 2108             3
# ...            ...
# 4812             5
# 3445             5
# 5057            11
# 3718             1
# 3863             1
#
# [5321 rows x 12 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/drive/MyDrive/Politician Trades/trades.csv'
trades.to_csv(file_path, index=False)
