# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/maxdokukin/Politician-Trades/main/Data/data/transactions_scraped.csv',
                 header = None)
df.columns = ["Politician Name", "Party", "Chamber", "State", "Issuer Name", "Ticker", "Publication Date",
              "Transaction Date", "Reporting Gap", "Owner", "Transaction Type", "Value Range", "Price",
              "Transaction ID"]

# %%
df.head()
# Out:
#   Politician Name       Party Chamber State          Issuer Name  Ticker  \
# 0      Tom Carper    Democrat  Senate    DE   Valero Energy Corp  VLO:US
# 1      Tom Carper    Democrat  Senate    DE         Enbridge Inc  ENB:US
# 2      Tom Carper    Democrat  Senate    DE  JPMorgan Chase & Co  JPM:US
# 3    Dan Newhouse  Republican   House    WA        Accenture PLC  ACN:US
# 4    Dan Newhouse  Republican   House    WA   Analog Devices Inc  ADI:US
#
#   Publication Date Transaction Date  Reporting Gap   Owner Transaction Type  \
# 0       2024-05-01       2024-04-11             19  Spouse             SELL
# 1       2024-05-01       2024-04-11             19  Spouse              BUY
# 2       2024-05-01       2024-04-01             29  Spouse             SELL
# 3       2024-04-26       2024-04-10             15  Spouse              BUY
# 4       2024-04-26       2024-04-10             15  Spouse              BUY
#
#   Value Range   Price  Transaction ID US Ticker  Price_0_days
# 0      1K–15K  177.04     10000062280       VLO    177.039993
# 1      1K–15K   34.55     10000062281       ENB     34.549999
# 2     15K–50K     NaN     10000062282       JPM    198.940002
# 3      1K–15K  324.40     20003772725       ACN    324.399994
# 4      1K–15K  196.33     20003772726       ADI    196.330002

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39114 entries, 0 to 39113
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Politician Name   39114 non-null  object
#  1   Party             39114 non-null  object
#  2   Chamber           39114 non-null  object
#  3   State             39114 non-null  object
#  4   Issuer Name       39114 non-null  object
#  5   Ticker            35041 non-null  object
#  6   Publication Date  39114 non-null  object
#  7   Transaction Date  39114 non-null  object
#  8   Reporting Gap     39114 non-null  int64
#  9   Owner             39114 non-null  object
#  10  Transaction Type  39114 non-null  object
#  11  Value Range       39114 non-null  object
#  12  Price             33186 non-null  object
#  13  Transaction ID    39114 non-null  int64
# dtypes: int64(2), object(12)
# memory usage: 4.2+ MB

# %%
df[["Politician Name", "Party", "Chamber", "State", "Issuer Name", "Ticker"]] = df[["Politician Name", "Party", "Chamber", "State", "Issuer Name", "Ticker"]].astype('string')

df['Transaction Date'] = df['Transaction Date'].str.replace('Sept', 'Sep')
df['Transaction Date'] = pd.to_datetime(df['Transaction Date']).dt.date

df['Publication Date'] = df['Publication Date'].str.replace('Sept', 'Sep')
df['Publication Date'] = df['Transaction Date'] + pd.to_timedelta(df['Reporting Gap'] + 1, unit='d')

df.Price = df.Price.str.replace(',', '').astype(float)

df['US Ticker'] = df[df['Ticker'].str.contains(':US')].Ticker.str.removesuffix(':US')
# Out:
# <ipython-input-4-f8d2a226c2ee>:7: PerformanceWarning: Adding/subtracting object-dtype array to TimedeltaArray not vectorized.
#   df['Publication Date'] = df['Transaction Date'] + pd.to_timedelta(df['Reporting Gap'] + 1, unit='d')

# %%
df.isna().sum()
# Out:
# Politician Name        0
# Party                  0
# Chamber                0
# State                  0
# Issuer Name            0
# Ticker                 0
# Publication Date       0
# Transaction Date       0
# Reporting Gap          0
# Owner                  0
# Transaction Type       0
# Value Range            0
# Price               1895
# Transaction ID         0
# dtype: int64

# %%
import yfinance as yf
from tqdm import tqdm

def fetch_closest_price(ticker_symbol, date):
    start_date = date - pd.Timedelta(days=3)
    end_date = date + pd.Timedelta(days=3)

    start_date_str = start_date.strftime('%Y-%m-%d')
    end_date_str = end_date.strftime('%Y-%m-%d')
    period = '1d'

    try:
        data = yf.download(ticker_symbol, start=start_date_str, end=end_date_str, interval=period, progress=False)
        data.dropna(subset=['Close'], inplace=True)
        data['date_diff'] = abs((data.index - date).days)
        data.sort_values('date_diff', inplace=True)

        return data.iloc[0]['Close'] if not data.empty else None
    except Exception as e:
        return None

days_offsets = [0]

for index, row in tqdm(df.iterrows(), total=df.shape[0], desc='Processing rows'):
    ticker = row['US Ticker']

    transaction_date = pd.to_datetime(row['Transaction Date'])

    for offset in days_offsets:
        offset_date = transaction_date + pd.Timedelta(days=offset)
        closest_price = fetch_closest_price(ticker, offset_date)

        if closest_price is not None:
            df.at[index, f'Price_{offset}_days'] = closest_price

print("Price updates complete.")
# Out:
# Streaming output truncated to the last 5000 lines.
# ERROR:yfinance:['JTSXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['JTSXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['JTSXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   0%|          | 146/35041 [00:17<27:35, 21.08it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['JTSXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   0%|          | 150/35041 [00:17<24:25, 23.81it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['JTSXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['OGVXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['JTSXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   0%|          | 154/35041 [00:17<21:43, 26.76it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['JTSXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['JTSXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['JTSXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['JTSXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   0%|          | 158/35041 [00:18<20:27, 28.43it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['JTSXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['JTSXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   0%|          | 173/35041 [00:18<22:27, 25.87it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['JTSXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   1%|          | 215/35041 [00:21<1:02:30,  9.29it/s]ERROR:yfinance:Failed to get ticker 'BRK/B' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK/B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   1%|          | 296/35041 [00:35<1:05:40,  8.82it/s]ERROR:yfinance:Failed to get ticker 'BRK/B' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK/B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   1%|          | 363/35041 [00:48<1:47:39,  5.37it/s]ERROR:yfinance:Failed to get ticker 'BF/A' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BF/A']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   1%|▏         | 464/35041 [01:04<2:00:00,  4.80it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['XSP']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2024-03-03 -> 2024-03-09)')
# Processing rows:   1%|▏         | 465/35041 [01:04<2:02:27,  4.71it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['XSP']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2024-03-10 -> 2024-03-16)')
# Processing rows:   1%|▏         | 466/35041 [01:04<1:51:17,  5.18it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['XSP']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2024-03-25 -> 2024-03-31)')
# Processing rows:   1%|▏         | 467/35041 [01:04<1:38:04,  5.88it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['XSP']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2024-03-18 -> 2024-03-24)')
# Processing rows:   1%|▏         | 494/35041 [01:09<1:20:12,  7.18it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ABB']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   1%|▏         | 516/35041 [01:13<1:40:57,  5.70it/s]ERROR:yfinance:Failed to get ticker 'BRK/B' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK/B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   2%|▏         | 572/35041 [01:21<1:30:27,  6.35it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['LTHM']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   2%|▏         | 573/35041 [01:22<3:04:08,  3.12it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['TE1']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   2%|▏         | 583/35041 [01:24<1:47:36,  5.34it/s]ERROR:yfinance:Failed to get ticker 'BRK/B' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK/B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   2%|▏         | 594/35041 [01:26<1:02:24,  9.20it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['JTSXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['JTSXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   2%|▏         | 597/35041 [01:26<51:27, 11.16it/s]  ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['JTSXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   2%|▏         | 612/35041 [01:28<59:04,  9.71it/s]  ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['JTSXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   2%|▏         | 615/35041 [01:28<1:23:14,  6.89it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['JTSXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   2%|▏         | 621/35041 [01:30<1:45:38,  5.43it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['JTSXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   2%|▏         | 624/35041 [01:30<1:37:41,  5.87it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['JTSXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['JTSXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['JTSXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   2%|▏         | 634/35041 [01:30<29:22, 19.52it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['JTSXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   2%|▏         | 645/35041 [01:30<18:02, 31.77it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['JTSXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   2%|▏         | 650/35041 [01:31<16:28, 34.79it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['JTSXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   2%|▏         | 744/35041 [01:42<1:24:19,  6.78it/s]ERROR:yfinance:Failed to get ticker 'BRK/B' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK/B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   3%|▎         | 881/35041 [02:02<1:32:05,  6.18it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['XSP']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2024-02-13 -> 2024-02-19)')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['XSP']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2024-02-20 -> 2024-02-26)')
# Processing rows:   3%|▎         | 883/35041 [02:02<1:08:14,  8.34it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['XSP']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2024-02-02 -> 2024-02-08)')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['XSP']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2024-02-09 -> 2024-02-15)')
# Processing rows:   3%|▎         | 891/35041 [02:03<1:13:28,  7.75it/s]ERROR:yfinance:Failed to get ticker 'BRK/B' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK/B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   3%|▎         | 919/35041 [02:08<1:10:20,  8.08it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['LTHM']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   3%|▎         | 930/35041 [02:10<1:13:12,  7.77it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['LTHM']: Exception('%ticker%: No timezone found, symbol may be delisted')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['LTHM']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   3%|▎         | 939/35041 [02:11<1:00:57,  9.32it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['LTHM']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   3%|▎         | 946/35041 [02:12<1:01:38,  9.22it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['LTHM']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   3%|▎         | 948/35041 [02:12<1:01:49,  9.19it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['LTHM']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   3%|▎         | 952/35041 [02:13<1:01:35,  9.23it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DE1']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   3%|▎         | 1064/35041 [02:26<39:02, 14.51it/s]ERROR:yfinance:Failed to get ticker 'BRK/B' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK/B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   3%|▎         | 1066/35041 [02:27<1:36:23,  5.87it/s]ERROR:yfinance:Failed to get ticker 'BRK/B' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK/B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   3%|▎         | 1071/35041 [02:27<55:35, 10.18it/s]  ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   3%|▎         | 1073/35041 [02:27<57:18,  9.88it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   3%|▎         | 1081/35041 [02:28<52:34, 10.77it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   3%|▎         | 1092/35041 [02:30<1:49:36,  5.16it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   3%|▎         | 1109/35041 [02:33<1:20:30,  7.02it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   3%|▎         | 1112/35041 [02:33<1:19:09,  7.14it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   3%|▎         | 1114/35041 [02:34<1:03:18,  8.93it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   3%|▎         | 1135/35041 [02:37<1:37:16,  5.81it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['OGVXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   3%|▎         | 1144/35041 [02:38<57:45,  9.78it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   3%|▎         | 1145/35041 [02:38<59:54,  9.43it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   3%|▎         | 1146/35041 [02:38<1:06:24,  8.51it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   3%|▎         | 1154/35041 [02:39<1:14:12,  7.61it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   3%|▎         | 1163/35041 [02:41<1:25:19,  6.62it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   3%|▎         | 1181/35041 [02:41<29:01, 19.44it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   3%|▎         | 1185/35041 [02:41<24:47, 22.76it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   3%|▎         | 1206/35041 [02:42<21:21, 26.41it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['OGVXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   3%|▎         | 1215/35041 [02:43<20:57, 26.90it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['PDRDY']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   4%|▍         | 1487/35041 [03:18<2:10:45,  4.28it/s]ERROR:yfinance:Failed to get ticker 'BRK/B' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK/B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   4%|▍         | 1520/35041 [03:25<2:27:51,  3.78it/s]ERROR:yfinance:Failed to get ticker 'BF/A' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BF/A']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   5%|▍         | 1592/35041 [03:38<1:10:16,  7.93it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['LBYAV']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   5%|▍         | 1653/35041 [03:45<1:03:12,  8.80it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['LTHM']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   5%|▍         | 1658/35041 [03:47<1:52:13,  4.96it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['XSP']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2024-01-06 -> 2024-01-12)')
# Processing rows:   5%|▍         | 1709/35041 [03:53<1:16:46,  7.24it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['WBK']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   5%|▌         | 1826/35041 [04:08<43:26, 12.75it/s]ERROR:yfinance:Failed to get ticker 'BRK/B' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK/B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   5%|▌         | 1828/35041 [04:09<1:44:20,  5.30it/s]ERROR:yfinance:Failed to get ticker 'BRK/B' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK/B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# ERROR:yfinance:Failed to get ticker 'BRK/B' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK/B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   5%|▌         | 1903/35041 [04:17<1:15:02,  7.36it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AMEH']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   5%|▌         | 1904/35041 [04:18<3:45:55,  2.44it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AMEH']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   6%|▌         | 1929/35041 [04:22<1:29:45,  6.15it/s]ERROR:yfinance:Failed to get ticker 'BRK/B' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK/B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   6%|▌         | 1950/35041 [04:25<37:10, 14.83it/s]ERROR:yfinance:Failed to get ticker 'BRK/B' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK/B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   6%|▌         | 1987/35041 [04:28<58:53,  9.35it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['MTBC']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   6%|▌         | 2088/35041 [04:43<1:47:18,  5.12it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AAIC']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   6%|▌         | 2107/35041 [04:47<1:39:30,  5.52it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['TRSWF']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   6%|▌         | 2185/35041 [04:56<53:27, 10.24it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   6%|▌         | 2187/35041 [04:57<1:02:39,  8.74it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   6%|▌         | 2189/35041 [04:57<1:05:28,  8.36it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   6%|▌         | 2190/35041 [04:57<1:05:56,  8.30it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   6%|▋         | 2259/35041 [05:07<45:58, 11.88it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   6%|▋         | 2261/35041 [05:08<44:46, 12.20it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   6%|▋         | 2263/35041 [05:08<47:09, 11.58it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   6%|▋         | 2265/35041 [05:08<46:58, 11.63it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   7%|▋         | 2313/35041 [05:11<57:11,  9.54it/s]ERROR:yfinance:Failed to get ticker 'BRK/B' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK/B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   7%|▋         | 2537/35041 [05:46<2:06:12,  4.29it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CDAY']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   7%|▋         | 2541/35041 [05:48<2:52:56,  3.13it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['PEAK']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   7%|▋         | 2583/35041 [05:55<1:20:09,  6.75it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['LBYAV']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   7%|▋         | 2586/35041 [05:56<2:20:02,  3.86it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['LBYAV']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   8%|▊         | 2640/35041 [06:04<1:35:43,  5.64it/s]ERROR:yfinance:Failed to get ticker 'BRK/B' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK/B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   8%|▊         | 2656/35041 [06:08<1:01:22,  8.79it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['XSP']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2023-10-29 -> 2023-11-04)')
# Processing rows:   8%|▊         | 2658/35041 [06:08<56:47,  9.50it/s]  ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['XSP']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2023-10-29 -> 2023-11-04)')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['XSP']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2023-11-25 -> 2023-12-01)')
# Processing rows:   8%|▊         | 2660/35041 [06:08<48:30, 11.13it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['XSP']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2023-11-12 -> 2023-11-18)')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['XSP']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2023-11-03 -> 2023-11-09)')
# Processing rows:   8%|▊         | 2680/35041 [06:11<49:23, 10.92it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AAIC']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   8%|▊         | 2749/35041 [06:19<47:07, 11.42it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   8%|▊         | 2751/35041 [06:19<44:05, 12.21it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Period 'max' is invalid, must be one of ['1d', '5d']
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   8%|▊         | 2753/35041 [06:19<42:01, 12.81it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   8%|▊         | 2755/35041 [06:20<46:42, 11.52it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   8%|▊         | 2757/35041 [06:20<47:12, 11.40it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   8%|▊         | 2759/35041 [06:20<53:50,  9.99it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   8%|▊         | 2761/35041 [06:20<56:35,  9.51it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   8%|▊         | 2793/35041 [06:25<1:10:51,  7.59it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['OGVXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   8%|▊         | 2837/35041 [06:27<35:54, 14.95it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   8%|▊         | 2840/35041 [06:27<36:59, 14.51it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   8%|▊         | 2842/35041 [06:28<40:07, 13.38it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   8%|▊         | 2845/35041 [06:28<33:06, 16.21it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   8%|▊         | 2849/35041 [06:28<26:24, 20.32it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CJTXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   8%|▊         | 2879/35041 [06:29<21:20, 25.12it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['OGVXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:   8%|▊         | 2890/35041 [06:29<18:05, 29.62it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['VMFXX']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2023-09-29 -> 2023-10-05)')
# Processing rows:   8%|▊         | 2896/35041 [06:30<38:01, 14.09it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['VMW']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   8%|▊         | 2906/35041 [06:32<1:14:17,  7.21it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ATVI']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   8%|▊         | 2907/35041 [06:33<2:04:44,  4.29it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ATVI']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   9%|▊         | 3040/35041 [06:49<1:01:42,  8.64it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['SGEN']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   9%|▉         | 3108/35041 [06:59<1:01:01,  8.72it/s]ERROR:yfinance:Failed to get ticker 'BRK/B' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK/B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   9%|▉         | 3264/35041 [07:22<1:00:06,  8.81it/s]ERROR:yfinance:Failed to get ticker 'BF/A' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BF/A']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   9%|▉         | 3282/35041 [07:25<1:23:16,  6.36it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CDAY']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   9%|▉         | 3289/35041 [07:26<1:28:41,  5.97it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['PEAK']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:   9%|▉         | 3324/35041 [07:33<1:29:14,  5.92it/s]ERROR:yfinance:Failed to get ticker 'BRK/B' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK/B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  10%|▉         | 3429/35041 [07:50<1:37:09,  5.42it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ATVI']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  10%|▉         | 3494/35041 [08:01<1:17:06,  6.82it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['SPX']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2023-10-21 -> 2023-10-27)')
# Processing rows:  10%|▉         | 3496/35041 [08:01<1:14:41,  7.04it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['SPX']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2023-10-15 -> 2023-10-21)')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['SPX']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2023-10-09 -> 2023-10-15)')
# Processing rows:  10%|▉         | 3498/35041 [08:01<57:44,  9.10it/s]  ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['SPX']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2023-10-02 -> 2023-10-08)')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['SPX']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2023-10-21 -> 2023-10-27)')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['SPX']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2023-10-15 -> 2023-10-21)')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['SPX']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2023-10-02 -> 2023-10-08)')
# Processing rows:  10%|█         | 3550/35041 [08:07<59:50,  8.77it/s]  ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['LBYAV']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  10%|█         | 3571/35041 [08:10<1:04:19,  8.15it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['LBYAV']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  10%|█         | 3642/35041 [08:18<49:08, 10.65it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ABB']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  11%|█         | 3743/35041 [08:33<1:24:56,  6.14it/s]ERROR:yfinance:Failed to get ticker 'BRK/B' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK/B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  11%|█         | 3744/35041 [08:34<2:52:47,  3.02it/s]ERROR:yfinance:Failed to get ticker 'BRK/B' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK/B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  11%|█         | 3923/35041 [08:59<1:30:52,  5.71it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['5672A']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  11%|█▏        | 3948/35041 [09:05<1:13:37,  7.04it/s]ERROR:yfinance:Failed to get ticker 'BRK/B' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK/B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  11%|█▏        | 4015/35041 [09:15<1:24:46,  6.10it/s]ERROR:yfinance:Failed to get ticker 'BRK/B' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK/B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  12%|█▏        | 4050/35041 [09:21<1:10:49,  7.29it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['VMFXX']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2023-09-09 -> 2023-09-15)')
# Processing rows:  12%|█▏        | 4070/35041 [09:24<59:18,  8.70it/s]  ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['OGVXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:  12%|█▏        | 4072/35041 [09:24<1:00:21,  8.55it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['OGVXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:  12%|█▏        | 4089/35041 [09:25<19:15, 26.78it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['VMFXX']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2023-09-09 -> 2023-09-15)')
# Processing rows:  12%|█▏        | 4108/35041 [09:25<13:33, 38.02it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['OGVXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['OGVXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:  12%|█▏        | 4170/35041 [09:32<50:15, 10.24it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ROLL']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  12%|█▏        | 4227/35041 [09:40<54:49,  9.37it/s]  ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['MMP']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  12%|█▏        | 4229/35041 [09:41<1:44:04,  4.93it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['MMP']: Exception('%ticker%: No timezone found, symbol may be delisted')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['MMP']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  12%|█▏        | 4241/35041 [09:42<1:05:57,  7.78it/s]ERROR:yfinance:Failed to get ticker 'BRK/B' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK/B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  12%|█▏        | 4245/35041 [09:44<2:24:08,  3.56it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['FZDXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:  12%|█▏        | 4272/35041 [09:48<1:13:26,  6.98it/s]ERROR:yfinance:Failed to get ticker 'BRK/B' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK/B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  13%|█▎        | 4469/35041 [10:19<1:11:27,  7.13it/s]ERROR:yfinance:Failed to get ticker 'BRK/B' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK/B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  13%|█▎        | 4515/35041 [10:27<1:15:35,  6.73it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['LTHM']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  13%|█▎        | 4525/35041 [10:29<1:39:46,  5.10it/s]ERROR:yfinance:Failed to get ticker 'BF/A' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BF/A']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  13%|█▎        | 4526/35041 [10:30<3:13:54,  2.62it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['PEAK']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  13%|█▎        | 4539/35041 [10:32<1:14:17,  6.84it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['LTHM']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  13%|█▎        | 4541/35041 [10:33<57:23,  8.86it/s]  ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['XSP']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2023-09-24 -> 2023-09-30)')
# Processing rows:  13%|█▎        | 4543/35041 [10:33<49:42, 10.23it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['XSP']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2023-09-24 -> 2023-09-30)')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['XSP']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2023-09-24 -> 2023-09-30)')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['XSP']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2023-09-04 -> 2023-09-10)')
# Processing rows:  13%|█▎        | 4547/35041 [10:33<32:18, 15.73it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['XSP']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2023-09-08 -> 2023-09-14)')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['XSP']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2023-09-11 -> 2023-09-17)')
# Processing rows:  13%|█▎        | 4549/35041 [10:33<32:44, 15.52it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['XSP']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2023-09-18 -> 2023-09-24)')
# Processing rows:  13%|█▎        | 4655/35041 [10:46<28:46, 17.60it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AAIC']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  13%|█▎        | 4658/35041 [10:47<1:14:10,  6.83it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['GPP']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  13%|█▎        | 4729/35041 [10:57<58:04,  8.70it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['OGVXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:  14%|█▎        | 4765/35041 [10:58<12:25, 40.60it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['OGVXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:  14%|█▎        | 4807/35041 [11:02<49:01, 10.28it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['RADI']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  14%|█▎        | 4809/35041 [11:04<2:35:16,  3.24it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['RADI']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  14%|█▍        | 4848/35041 [11:08<49:15, 10.22it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['LLYVK']: Exception("%ticker%: Data doesn't exist for startDate = 1690862400, endDate = 1691380800")
# Processing rows:  14%|█▍        | 4850/35041 [11:09<1:38:25,  5.11it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['LLYVK']: Exception("%ticker%: Data doesn't exist for startDate = 1690862400, endDate = 1691380800")
# Processing rows:  14%|█▍        | 4859/35041 [11:10<1:00:20,  8.34it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['WTT']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  14%|█▍        | 4861/35041 [11:11<1:41:47,  4.94it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['WTT']: Exception('%ticker%: No timezone found, symbol may be delisted')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['WTT']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  14%|█▍        | 4869/35041 [11:11<1:06:14,  7.59it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ATVI']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  14%|█▍        | 4870/35041 [11:12<2:10:01,  3.87it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ATVI']: Exception('%ticker%: No timezone found, symbol may be delisted')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ATVI']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  14%|█▍        | 4885/35041 [11:14<1:19:50,  6.30it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['MMP']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  14%|█▍        | 4977/35041 [11:27<1:08:50,  7.28it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['PEAK']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  14%|█▍        | 4983/35041 [11:29<1:35:38,  5.24it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CDAY']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  14%|█▍        | 4990/35041 [11:30<1:39:39,  5.03it/s]ERROR:yfinance:Failed to get ticker 'BRK/B' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK/B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  14%|█▍        | 5071/35041 [11:44<1:30:38,  5.51it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['LTHM']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  14%|█▍        | 5080/35041 [11:46<1:10:29,  7.08it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['LTHM']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  15%|█▍        | 5109/35041 [11:49<1:11:46,  6.95it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['LTHM']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  15%|█▍        | 5136/35041 [11:52<47:32, 10.49it/s]ERROR:yfinance:Failed to get ticker 'BRK/B' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK/B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  15%|█▍        | 5143/35041 [11:54<1:32:31,  5.39it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['XSP']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2023-07-29 -> 2023-08-04)')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['XSP']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2023-08-21 -> 2023-08-27)')
# Processing rows:  15%|█▍        | 5145/35041 [11:55<1:13:24,  6.79it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['XSP']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2023-08-27 -> 2023-09-02)')
# Processing rows:  15%|█▍        | 5146/35041 [11:55<1:09:55,  7.12it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['XSP']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2023-08-05 -> 2023-08-11)')
# Processing rows:  15%|█▍        | 5239/35041 [12:07<54:46,  9.07it/s]  ERROR:yfinance:Failed to get ticker 'BRK/B' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK/B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  15%|█▌        | 5282/35041 [12:12<40:56, 12.12it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['1494391D']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  15%|█▌        | 5414/35041 [12:29<1:18:04,  6.33it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['OGVXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:  16%|█▌        | 5452/35041 [12:31<18:57, 26.01it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['OGVXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:  16%|█▌        | 5517/35041 [12:38<2:02:07,  4.03it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ABB']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  16%|█▌        | 5550/35041 [12:46<1:33:09,  5.28it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ANZBY']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  16%|█▌        | 5594/35041 [12:56<2:05:14,  3.92it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CAJ']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  16%|█▌        | 5643/35041 [13:06<1:49:44,  4.46it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DPSGY']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  16%|█▌        | 5648/35041 [13:08<2:28:32,  3.30it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DISH']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  16%|█▌        | 5681/35041 [13:14<53:23,  9.17it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['FRRVY']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  16%|█▋        | 5704/35041 [13:19<1:35:22,  5.13it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['PEAK']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  16%|█▋        | 5717/35041 [13:23<1:31:10,  5.36it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HHC']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  16%|█▋        | 5771/35041 [13:34<1:18:09,  6.24it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['LBYAV']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  16%|█▋        | 5772/35041 [13:34<2:46:15,  2.93it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['LBYAV']: Exception('%ticker%: No timezone found, symbol may be delisted')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['LSI']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  17%|█▋        | 5822/35041 [13:42<1:02:14,  7.82it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['NCMGY']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  17%|█▋        | 5858/35041 [13:49<1:33:29,  5.20it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['PDRDY']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  17%|█▋        | 5888/35041 [13:56<2:06:07,  3.85it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['RPT']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  17%|█▋        | 5965/35041 [14:11<1:50:23,  4.39it/s]ERROR:yfinance:
# 1 Failed download:
# ...
# Processing rows:  97%|█████████▋| 34058/35041 [1:16:37<05:20,  3.07it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['PBFX']: Exception('%ticker%: No timezone found, symbol may be delisted')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['SHLX']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  97%|█████████▋| 34060/35041 [1:16:38<06:41,  2.45it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['SHLX']: Exception('%ticker%: No timezone found, symbol may be delisted')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['TDDXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:  97%|█████████▋| 34062/35041 [1:16:38<04:28,  3.64it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['TDDXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:  97%|█████████▋| 34063/35041 [1:16:38<03:55,  4.15it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['TDDXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:  97%|█████████▋| 34064/35041 [1:16:38<03:24,  4.79it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['TDDXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:  97%|█████████▋| 34065/35041 [1:16:38<03:00,  5.42it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['TDDXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:  97%|█████████▋| 34066/35041 [1:16:38<02:39,  6.10it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['TDDXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['TDDXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['TDDXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:  97%|█████████▋| 34104/35041 [1:16:43<02:02,  7.66it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['TPCO']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  97%|█████████▋| 34108/35041 [1:16:45<03:17,  4.74it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CERN']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  97%|█████████▋| 34115/35041 [1:16:46<02:56,  5.23it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  97%|█████████▋| 34118/35041 [1:16:47<03:59,  3.85it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['VAR']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  97%|█████████▋| 34142/35041 [1:16:51<01:36,  9.35it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['LHCG']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  98%|█████████▊| 34171/35041 [1:16:56<02:01,  7.16it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DISH']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  98%|█████████▊| 34202/35041 [1:17:02<01:57,  7.15it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DISH']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  98%|█████████▊| 34284/35041 [1:17:09<01:32,  8.20it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ENBL']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  98%|█████████▊| 34289/35041 [1:17:10<02:23,  5.25it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['PBFX']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  98%|█████████▊| 34290/35041 [1:17:11<04:20,  2.88it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['SHLX']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  98%|█████████▊| 34293/35041 [1:17:12<03:40,  3.39it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['FSKR']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  98%|█████████▊| 34303/35041 [1:17:14<02:32,  4.85it/s]ERROR:yfinance:Failed to get ticker 'BRK/B' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK/B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  98%|█████████▊| 34328/35041 [1:17:19<01:40,  7.07it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['FRC']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  98%|█████████▊| 34347/35041 [1:17:23<02:06,  5.51it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ZNGA']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  98%|█████████▊| 34350/35041 [1:17:24<02:58,  3.87it/s]ERROR:yfinance:Failed to get ticker 'BRK/B' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK/B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  98%|█████████▊| 34373/35041 [1:17:25<00:23, 28.32it/s]ERROR:yfinance:Failed to get ticker 'BRK/B' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK/B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  98%|█████████▊| 34392/35041 [1:17:26<00:16, 39.58it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['FRC']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  98%|█████████▊| 34402/35041 [1:17:26<00:15, 40.50it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ZNGA']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  98%|█████████▊| 34440/35041 [1:17:30<01:01,  9.77it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['VAR']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  98%|█████████▊| 34452/35041 [1:17:32<01:27,  6.73it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['MMP']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  98%|█████████▊| 34453/35041 [1:17:33<02:59,  3.27it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['MMP']: Exception('%ticker%: No timezone found, symbol may be delisted')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['MMP']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  98%|█████████▊| 34461/35041 [1:17:34<01:27,  6.61it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ENBL']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  98%|█████████▊| 34471/35041 [1:17:36<01:29,  6.36it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['PBFX']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  98%|█████████▊| 34472/35041 [1:17:37<03:19,  2.85it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['PBFX']: Exception('%ticker%: No timezone found, symbol may be delisted')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['PBFX']: Exception('%ticker%: No timezone found, symbol may be delisted')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['SHLX']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  98%|█████████▊| 34484/35041 [1:17:39<01:46,  5.25it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['FDRXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:  98%|█████████▊| 34487/35041 [1:17:39<01:34,  5.86it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BOWX']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  99%|█████████▊| 34556/35041 [1:17:48<00:46, 10.43it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['TWTR']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  99%|█████████▊| 34585/35041 [1:17:52<00:48,  9.40it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CWEN.A']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  99%|█████████▊| 34591/35041 [1:17:53<01:19,  5.63it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DSEY']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  99%|█████████▊| 34602/35041 [1:17:55<00:48,  9.04it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HHC']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  99%|█████████▉| 34604/35041 [1:17:56<01:39,  4.40it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HHC']: Exception('%ticker%: No timezone found, symbol may be delisted')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HHC']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  99%|█████████▉| 34607/35041 [1:17:56<01:05,  6.67it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['NUAN']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  99%|█████████▉| 34609/35041 [1:17:57<01:40,  4.32it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['TRIT']: Exception("%ticker%: Data doesn't exist for startDate = 1618027200, endDate = 1618545600")
# Processing rows:  99%|█████████▉| 34611/35041 [1:17:58<01:59,  3.60it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CWEN.A']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  99%|█████████▉| 34631/35041 [1:18:00<00:55,  7.34it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['TDDXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:  99%|█████████▉| 34632/35041 [1:18:00<00:52,  7.79it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['TDDXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['TDDXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:  99%|█████████▉| 34634/35041 [1:18:00<00:38, 10.51it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['TDDXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['TDDXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows:  99%|█████████▉| 34646/35041 [1:18:01<00:32, 12.27it/s]ERROR:yfinance:Failed to get ticker 'BRK/B' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK/B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  99%|█████████▉| 34652/35041 [1:18:03<00:53,  7.34it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BPMP']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  99%|█████████▉| 34659/35041 [1:18:04<00:49,  7.65it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['SHLX']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  99%|█████████▉| 34660/35041 [1:18:04<01:37,  3.93it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['SHLX']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  99%|█████████▉| 34688/35041 [1:18:08<00:37,  9.39it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ACF']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2021-03-15 -> 2021-03-21)')
# Processing rows:  99%|█████████▉| 34737/35041 [1:18:15<01:06,  4.54it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['OCSI']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  99%|█████████▉| 34787/35041 [1:18:21<00:20, 12.42it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['TWTR']: Exception('%ticker%: No timezone found, symbol may be delisted')
# ERROR:yfinance:Failed to get ticker 'BRK/B' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK/B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  99%|█████████▉| 34836/35041 [1:18:26<00:18, 11.28it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['INFO']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  99%|█████████▉| 34843/35041 [1:18:28<00:32,  6.08it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['INFO']: Exception('%ticker%: No timezone found, symbol may be delisted')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['INFO']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  99%|█████████▉| 34856/35041 [1:18:29<00:19,  9.51it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ZNGA']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows:  99%|█████████▉| 34858/35041 [1:18:30<00:38,  4.81it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ZNGA']: Exception('%ticker%: No timezone found, symbol may be delisted')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ZNGA']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows: 100%|█████████▉| 34904/35041 [1:18:34<00:18,  7.34it/s]ERROR:yfinance:Failed to get ticker 'BRK/B' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK/B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows: 100%|█████████▉| 34905/35041 [1:18:35<00:40,  3.35it/s]ERROR:yfinance:Failed to get ticker 'BRK/B' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK/B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# ERROR:yfinance:Failed to get ticker 'BRK/B' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK/B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# ERROR:yfinance:Failed to get ticker 'BRK/B' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK/B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# ERROR:yfinance:Failed to get ticker 'BRK/B' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK/B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['MMP']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows: 100%|█████████▉| 34910/35041 [1:18:36<00:30,  4.25it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['MMP']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows: 100%|█████████▉| 34949/35041 [1:18:40<00:07, 12.08it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CWEN.A']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows: 100%|█████████▉| 34956/35041 [1:18:41<00:12,  6.96it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CERN']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows: 100%|█████████▉| 34978/35041 [1:18:46<00:07,  8.38it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['TDDXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['TDDXX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Processing rows: 100%|█████████▉| 35006/35041 [1:18:50<00:05,  6.27it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['FGTXX']: Exception("%ticker%: Data doesn't exist for startDate = 1616385600, endDate = 1616904000")
# Processing rows: 100%|█████████▉| 35039/35041 [1:18:54<00:00, 12.69it/s]ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['MMP']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Processing rows: 100%|██████████| 35041/35041 [1:18:55<00:00,  7.40it/s]
# Price updates complete.

# %%
df.isna().sum()
# Out:
# Politician Name        0
# Party                  0
# Chamber                0
# State                  0
# Issuer Name            0
# Ticker                 0
# Publication Date       0
# Transaction Date       0
# Reporting Gap          0
# Owner                  0
# Transaction Type       0
# Value Range            0
# Price               1895
# Transaction ID         0
# US Ticker            106
# Price_0_days        1825
# dtype: int64

# %%
import numpy as np

bins = {
    "< 1K": (0, 1000),
    "1K–15K": (1000, 15000),
    "15K–50K": (15000, 50000),
    "50K–100K": (50000, 100000),
    "100K–250K": (100000, 250000),
    "250K–500K": (250000, 500000),
    "500K–1M": (500000, 1000000),
    "1M–5M": (1000000, 5000000),
    "5M–25M": (5000000, 25000000),
}

midpoints = {bin: (range[0] + range[1]) / 2 for bin, range in bins.items()}

df['Approx Transaction Amount'] = df['Value Range'].map(midpoints)
df['Approx Share Count'] = np.floor(df['Approx Transaction Amount'] / df['Price'])

# %%
df.drop(df[df['US Ticker'].isna()].index, inplace=True)
df['Ticker'] = df['US Ticker']
df.drop(['US Ticker'], axis=1, inplace = True)

df.drop(df[df['Price'].isna()].index, inplace=True)
df.drop(df[df['Price'] == 1].index, inplace=True)

df.drop(df[df['Price_0_days'].isna()].index, inplace=True)

# %%
df.isna().sum()
# Out:
# Politician Name              0
# Party                        0
# Chamber                      0
# State                        0
# Issuer Name                  0
# Ticker                       0
# Publication Date             0
# Transaction Date             0
# Reporting Gap                0
# Owner                        0
# Transaction Type             0
# Value Range                  0
# Price                        0
# Transaction ID               0
# Price_0_days                 0
# Approx Transaction Amount    0
# Approx Share Count           0
# dtype: int64

# %%
df.head()
# Out:
#   Politician Name       Party Chamber State           Issuer Name Ticker  \
# 0      Tom Carper    Democrat  Senate    DE    Valero Energy Corp    VLO
# 1      Tom Carper    Democrat  Senate    DE          Enbridge Inc    ENB
# 3    Dan Newhouse  Republican   House    WA         Accenture PLC    ACN
# 4    Dan Newhouse  Republican   House    WA    Analog Devices Inc    ADI
# 6    Dan Newhouse  Republican   House    WA  Booking Holdings Inc   BKNG
#
#   Publication Date Transaction Date  Reporting Gap   Owner Transaction Type  \
# 0       2024-05-01       2024-04-11             19  Spouse             SELL
# 1       2024-05-01       2024-04-11             19  Spouse              BUY
# 3       2024-04-26       2024-04-10             15  Spouse              BUY
# 4       2024-04-26       2024-04-10             15  Spouse              BUY
# 6       2024-04-26       2024-04-10             15  Spouse             SELL
#
#   Value Range    Price  Transaction ID  Price_0_days  \
# 0      1K–15K   177.04     10000062280    177.039993
# 1      1K–15K    34.55     10000062281     34.549999
# 3      1K–15K   324.40     20003772725    324.399994
# 4      1K–15K   196.33     20003772726    196.330002
# 6      1K–15K  3586.13     20003772728   3586.129883
#
#    Approx Transaction Amount  Approx Share Count
# 0                     8000.0                45.0
# 1                     8000.0               231.0
# 3                     8000.0                24.0
# 4                     8000.0                40.0
# 6                     8000.0                 2.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31589 entries, 0 to 39112
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Politician Name            31589 non-null  string
#  1   Party                      31589 non-null  string
#  2   Chamber                    31589 non-null  string
#  3   State                      31589 non-null  string
#  4   Issuer Name                31589 non-null  string
#  5   Ticker                     31589 non-null  string
#  6   Publication Date           31589 non-null  object
#  7   Transaction Date           31589 non-null  object
#  8   Reporting Gap              31589 non-null  int64
#  9   Owner                      31589 non-null  object
#  10  Transaction Type           31589 non-null  object
#  11  Value Range                31589 non-null  object
#  12  Price                      31589 non-null  float64
#  13  Transaction ID             31589 non-null  int64
#  14  Price_0_days               31589 non-null  float64
#  15  Approx Transaction Amount  31589 non-null  float64
#  16  Approx Share Count         31589 non-null  float64
# dtypes: float64(4), int64(2), object(5), string(6)
# memory usage: 5.3+ MB

# %%
file_path = '/content/drive/MyDrive/Politician Trades/transactions_cleaned.csv'
df.to_csv(file_path, index=False)
